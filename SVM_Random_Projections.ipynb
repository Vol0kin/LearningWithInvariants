# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches

from lusi.svm import SVMIRandomProjections
from lusi.invariants import *

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

# %%
diabetes_df = pd.read_csv('data/diabetes.csv')
diabetes_df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
# Get the data and split it in train and test
X, y = diabetes_df.drop('Outcome', axis=1).values, diabetes_df['Outcome'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=47)

# %%
# Scale the data
scaler = StandardScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Run experiments
accuracies = []

for num_invariants in range(1, 9):
    print(f'Running with {num_invariants} invariants...')
    invariant_accuracies = []

    for _ in range(1000):
        svm_rp = SVMIRandomProjections(C=1, kernel='rbf', gamma='auto', delta=0.001)
        svm_rp.fit(X_train_scaled, y_train, num_invariants=num_invariants)
        y_pred = svm_rp.predict(X_test_scaled)
        acc = accuracy_score(y_test, y_pred)
        invariant_accuracies.append(acc)
    
    accuracies.append(invariant_accuracies)
# Out:
# Running with 1 invariants...
# Running with 2 invariants...
# Running with 3 invariants...
# Running with 4 invariants...
# Running with 5 invariants...
# Running with 6 invariants...
# Running with 7 invariants...
# Running with 8 invariants...

# %%
plt.boxplot(accuracies)
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
plt.violinplot(accuracies)
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
plt.boxplot(accuracies[3:], positions=range(4, 9))
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
plt.violinplot(accuracies[3:], positions=range(4, 9))
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
svm_baseline = SVMIRandomProjections(C=1, kernel='rbf', gamma='auto', delta=0.001)
svm_baseline.fit(X_train_scaled, y_train, num_invariants=0)
y_pred = svm_baseline.predict(X_test_scaled)
acc_baseline = accuracy_score(y_test, y_pred)

print(f'Baseline accuracy: {acc_baseline}')


for inv, acc in enumerate(accuracies):
    acc_arr = np.array(acc)
    n_high_acc_baseline = len(np.where(acc_arr >= acc_baseline)[0])
    n_high_acc = len(np.where(acc_arr > acc_baseline)[0])
    max_acc = np.max(acc_arr)
    print(f'\nNumber of elements with accuracy >= {acc_baseline} using {inv + 1} invariants: {n_high_acc_baseline}')
    print(f'Number of elements with accuracy > {acc_baseline} using {inv + 1} invariants: {n_high_acc}')
    print(f'Max. accuracy: {max_acc}')
# Out:
# Baseline accuracy: 0.7792207792207793
#
# Number of elements with accuracy >= 0.7792207792207793 using 1 invariants: 199
# Number of elements with accuracy > 0.7792207792207793 using 1 invariants: 0
# Max. accuracy: 0.7792207792207793
#
# Number of elements with accuracy >= 0.7792207792207793 using 2 invariants: 387
# Number of elements with accuracy > 0.7792207792207793 using 2 invariants: 9
# Max. accuracy: 0.7857142857142857
#
# Number of elements with accuracy >= 0.7792207792207793 using 3 invariants: 394
# Number of elements with accuracy > 0.7792207792207793 using 3 invariants: 27
# Max. accuracy: 0.7857142857142857
#
# Number of elements with accuracy >= 0.7792207792207793 using 4 invariants: 368
# Number of elements with accuracy > 0.7792207792207793 using 4 invariants: 25
# Max. accuracy: 0.7857142857142857
#
# Number of elements with accuracy >= 0.7792207792207793 using 5 invariants: 323
# Number of elements with accuracy > 0.7792207792207793 using 5 invariants: 38
# Max. accuracy: 0.7922077922077922
#
# Number of elements with accuracy >= 0.7792207792207793 using 6 invariants: 270
# Number of elements with accuracy > 0.7792207792207793 using 6 invariants: 52
# Max. accuracy: 0.7922077922077922
#
# Number of elements with accuracy >= 0.7792207792207793 using 7 invariants: 134
# Number of elements with accuracy > 0.7792207792207793 using 7 invariants: 27
# Max. accuracy: 0.7922077922077922
#
# Number of elements with accuracy >= 0.7792207792207793 using 8 invariants: 0
# Number of elements with accuracy > 0.7792207792207793 using 8 invariants: 0
# Max. accuracy: 0.7727272727272727

# %%
# Run experiments
accuracies = []

for num_invariants in range(1, 9):
    print(f'Running with {num_invariants} invariants...')
    invariant_accuracies = []

    for _ in range(1000):
        svm_rp = SVMIRandomProjections(C=1, kernel='rbf', gamma='auto', delta=0.3)
        svm_rp.fit(X_train_scaled, y_train, num_invariants=num_invariants)
        y_pred = svm_rp.predict(X_test_scaled)
        acc = accuracy_score(y_test, y_pred)
        invariant_accuracies.append(acc)
    
    accuracies.append(invariant_accuracies)
# Out:
# Running with 1 invariants...
# Running with 2 invariants...
# Running with 3 invariants...
# Running with 4 invariants...
# Running with 5 invariants...
# Running with 6 invariants...
# Running with 7 invariants...
# Running with 8 invariants...

# %%
plt.boxplot(accuracies)
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
plt.violinplot(accuracies)
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
plt.boxplot(accuracies[3:], positions=range(4, 9))
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
plt.violinplot(accuracies[3:], positions=range(4, 9))
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
svm_baseline = SVMIRandomProjections(C=1, kernel='rbf', gamma='auto', delta=0.001)
svm_baseline.fit(X_train_scaled, y_train, num_invariants=0, tolerance=10)
y_pred = svm_baseline.predict(X_test_scaled)
acc_baseline = accuracy_score(y_test, y_pred)

print(f'Baseline accuracy: {acc_baseline}')


for inv, acc in enumerate(accuracies):
    acc_arr = np.array(acc)
    n_high_acc_baseline = len(np.where(acc_arr >= acc_baseline)[0])
    n_high_acc = len(np.where(acc_arr > acc_baseline)[0])
    max_acc = np.max(acc_arr)
    print(f'\nNumber of elements with accuracy >= {acc_baseline} using {inv + 1} invariants: {n_high_acc_baseline}')
    print(f'Number of elements with accuracy > {acc_baseline} using {inv + 1} invariants: {n_high_acc}')
    print(f'Max. accuracy: {max_acc}')
# Out:
# Baseline accuracy: 0.7792207792207793
#
# Number of elements with accuracy >= 0.7792207792207793 using 1 invariants: 209
# Number of elements with accuracy > 0.7792207792207793 using 1 invariants: 2
# Max. accuracy: 0.7857142857142857
#
# Number of elements with accuracy >= 0.7792207792207793 using 2 invariants: 384
# Number of elements with accuracy > 0.7792207792207793 using 2 invariants: 5
# Max. accuracy: 0.7857142857142857
#
# Number of elements with accuracy >= 0.7792207792207793 using 3 invariants: 469
# Number of elements with accuracy > 0.7792207792207793 using 3 invariants: 17
# Max. accuracy: 0.7857142857142857
#
# Number of elements with accuracy >= 0.7792207792207793 using 4 invariants: 467
# Number of elements with accuracy > 0.7792207792207793 using 4 invariants: 5
# Max. accuracy: 0.7857142857142857
#
# Number of elements with accuracy >= 0.7792207792207793 using 5 invariants: 481
# Number of elements with accuracy > 0.7792207792207793 using 5 invariants: 12
# Max. accuracy: 0.7857142857142857
#
# Number of elements with accuracy >= 0.7792207792207793 using 6 invariants: 549
# Number of elements with accuracy > 0.7792207792207793 using 6 invariants: 18
# Max. accuracy: 0.7857142857142857
#
# Number of elements with accuracy >= 0.7792207792207793 using 7 invariants: 497
# Number of elements with accuracy > 0.7792207792207793 using 7 invariants: 39
# Max. accuracy: 0.7922077922077922
#
# Number of elements with accuracy >= 0.7792207792207793 using 8 invariants: 0
# Number of elements with accuracy > 0.7792207792207793 using 8 invariants: 0
# Max. accuracy: 0.7727272727272727

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.1, random_state=47)

# Scale the data
scaler = StandardScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Run experiments
accuracies = []

for num_invariants in range(1, 9):
    print(f'Running with {num_invariants} invariants...')
    invariant_accuracies = []

    for _ in range(1000):
        svm_rp = SVMIRandomProjections(C=1, kernel='rbf', gamma='auto', delta=0.001)
        svm_rp.fit(X_train_scaled, y_train, num_invariants=num_invariants)
        y_pred = svm_rp.predict(X_test_scaled)
        acc = accuracy_score(y_test, y_pred)
        invariant_accuracies.append(acc)
    
    accuracies.append(invariant_accuracies)
# Out:
# Running with 1 invariants...
# Running with 2 invariants...
# Running with 3 invariants...
# Running with 4 invariants...
# Running with 5 invariants...
# Running with 6 invariants...
# Running with 7 invariants...
# Running with 8 invariants...

# %%
plt.boxplot(accuracies)
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
plt.violinplot(accuracies)
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
plt.boxplot(accuracies[3:], positions=range(4, 9))
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
plt.violinplot(accuracies[3:], positions=range(4, 9))
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
svm_baseline = SVMIRandomProjections(C=1, kernel='rbf', gamma='auto', delta=0.001)
svm_baseline.fit(X_train_scaled, y_train, num_invariants=0, tolerance=10)
y_pred = svm_baseline.predict(X_test_scaled)
acc_baseline = accuracy_score(y_test, y_pred)

print(f'Baseline accuracy: {acc_baseline}')


for inv, acc in enumerate(accuracies):
    acc_arr = np.array(acc)
    n_high_acc_baseline = len(np.where(acc_arr >= acc_baseline)[0])
    n_high_acc = len(np.where(acc_arr > acc_baseline)[0])
    max_acc = np.max(acc_arr)
    print(f'\nNumber of elements with accuracy >= {acc_baseline} using {inv + 1} invariants: {n_high_acc_baseline}')
    print(f'Number of elements with accuracy > {acc_baseline} using {inv + 1} invariants: {n_high_acc}')
    print(f'Max. accuracy: {max_acc}')
# Out:
# Baseline accuracy: 0.7456647398843931
#
# Number of elements with accuracy >= 0.7456647398843931 using 1 invariants: 330
# Number of elements with accuracy > 0.7456647398843931 using 1 invariants: 238
# Max. accuracy: 0.7586705202312138
#
# Number of elements with accuracy >= 0.7456647398843931 using 2 invariants: 392
# Number of elements with accuracy > 0.7456647398843931 using 2 invariants: 317
# Max. accuracy: 0.7615606936416185
#
# Number of elements with accuracy >= 0.7456647398843931 using 3 invariants: 432
# Number of elements with accuracy > 0.7456647398843931 using 3 invariants: 362
# Max. accuracy: 0.7601156069364162
#
# Number of elements with accuracy >= 0.7456647398843931 using 4 invariants: 369
# Number of elements with accuracy > 0.7456647398843931 using 4 invariants: 303
# Max. accuracy: 0.7586705202312138
#
# Number of elements with accuracy >= 0.7456647398843931 using 5 invariants: 291
# Number of elements with accuracy > 0.7456647398843931 using 5 invariants: 241
# Max. accuracy: 0.7615606936416185
#
# Number of elements with accuracy >= 0.7456647398843931 using 6 invariants: 169
# Number of elements with accuracy > 0.7456647398843931 using 6 invariants: 146
# Max. accuracy: 0.7572254335260116
#
# Number of elements with accuracy >= 0.7456647398843931 using 7 invariants: 58
# Number of elements with accuracy > 0.7456647398843931 using 7 invariants: 51
# Max. accuracy: 0.7557803468208093
#
# Number of elements with accuracy >= 0.7456647398843931 using 8 invariants: 0
# Number of elements with accuracy > 0.7456647398843931 using 8 invariants: 0
# Max. accuracy: 0.7326589595375722

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.05, random_state=47)

# Scale the data
scaler = StandardScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Run experiments
accuracies = []

for num_invariants in range(1, 9):
    print(f'Running with {num_invariants} invariants...')
    invariant_accuracies = []

    for _ in range(1000):
        svm_rp = SVMIRandomProjections(C=1, kernel='rbf', gamma='auto', delta=0.001)
        svm_rp.fit(X_train_scaled, y_train, num_invariants=num_invariants)
        y_pred = svm_rp.predict(X_test_scaled)
        acc = accuracy_score(y_test, y_pred)
        invariant_accuracies.append(acc)
    
    accuracies.append(invariant_accuracies)
# Out:
# Running with 1 invariants...
# Running with 2 invariants...
# Running with 3 invariants...
# Running with 4 invariants...
# Running with 5 invariants...
# Running with 6 invariants...
# Running with 7 invariants...
# Running with 8 invariants...

# %%
plt.boxplot(accuracies)
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
plt.violinplot(accuracies)
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
plt.boxplot(accuracies[3:], positions=range(4, 9))
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
plt.violinplot(accuracies[3:], positions=range(4, 9))
plt.grid()
plt.xlabel('Number of invariants')
plt.ylabel('Accuracy')
plt.plot()
# Out:
# []

# %%
svm_baseline = SVMIRandomProjections(C=1, kernel='rbf', gamma='auto', delta=0.001)
svm_baseline.fit(X_train_scaled, y_train, num_invariants=0, tolerance=10)
y_pred = svm_baseline.predict(X_test_scaled)
acc_baseline = accuracy_score(y_test, y_pred)

print(f'Baseline accuracy: {acc_baseline}')


for inv, acc in enumerate(accuracies):
    acc_arr = np.array(acc)
    n_high_acc_baseline = len(np.where(acc_arr >= acc_baseline)[0])
    n_high_acc = len(np.where(acc_arr > acc_baseline)[0])
    max_acc = np.max(acc_arr)
    print(f'\nNumber of elements with accuracy >= {acc_baseline} using {inv + 1} invariants: {n_high_acc_baseline}')
    print(f'Number of elements with accuracy > {acc_baseline} using {inv + 1} invariants: {n_high_acc}')
    print(f'Max. accuracy: {max_acc}')
# Out:
# Baseline accuracy: 0.684931506849315
#
# Number of elements with accuracy >= 0.684931506849315 using 1 invariants: 539
# Number of elements with accuracy > 0.684931506849315 using 1 invariants: 430
# Max. accuracy: 0.7054794520547946
#
# Number of elements with accuracy >= 0.684931506849315 using 2 invariants: 567
# Number of elements with accuracy > 0.684931506849315 using 2 invariants: 488
# Max. accuracy: 0.7041095890410959
#
# Number of elements with accuracy >= 0.684931506849315 using 3 invariants: 504
# Number of elements with accuracy > 0.684931506849315 using 3 invariants: 429
# Max. accuracy: 0.7054794520547946
#
# Number of elements with accuracy >= 0.684931506849315 using 4 invariants: 398
# Number of elements with accuracy > 0.684931506849315 using 4 invariants: 357
# Max. accuracy: 0.7095890410958904
#
# Number of elements with accuracy >= 0.684931506849315 using 5 invariants: 280
# Number of elements with accuracy > 0.684931506849315 using 5 invariants: 256
# Max. accuracy: 0.7054794520547946
#
# Number of elements with accuracy >= 0.684931506849315 using 6 invariants: 161
# Number of elements with accuracy > 0.684931506849315 using 6 invariants: 137
# Max. accuracy: 0.7041095890410959
#
# Number of elements with accuracy >= 0.684931506849315 using 7 invariants: 50
# Number of elements with accuracy > 0.684931506849315 using 7 invariants: 41
# Max. accuracy: 0.7082191780821918
#
# Number of elements with accuracy >= 0.684931506849315 using 8 invariants: 0
# Number of elements with accuracy > 0.684931506849315 using 8 invariants: 0
# Max. accuracy: 0.6547945205479452
